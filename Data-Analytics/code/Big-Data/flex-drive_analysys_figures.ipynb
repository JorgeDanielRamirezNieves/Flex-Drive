# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_FlexDrive = pd.read_csv('../../docs/poblaciones/df_FlexDrive_Insights.csv', sep=';')

# %%
df_FlexDrive['P2-Edad'].value_counts().plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('[Título de la Gráfica]]')
plt.xlabel('[Título del Eje X]]')
plt.ylabel('[Título del Eje Y]]')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Probando Seaborn para graficar, seccionar respuestas múltiples para contestar P7, ignorando NaNs
df_FlexDrive['P7-Actividad_Actual_Multi'].str.split(';', expand=True).stack().reset_index(drop=True).explode().value_counts().plot(kind='bar', figsize=(10, 6), color='lightgreen')

#Colocar número sobre barras
for index, value in enumerate(df_FlexDrive['P7-Actividad_Actual_Multi'].str.split(';', expand=True).stack().reset_index(drop=True).explode().value_counts()):
    plt.text(index, value, str(value), ha='center', va='bottom')
    
# Arreglar marco de gráfica para que no se corte el título y etiquetas


plt.title('[Título de la Gráfica]]')
plt.xlabel('[Título del Eje X]]')
plt.ylabel('[Título del Eje Y]]')
plt.xticks(rotation=90)
plt.tight_layout()

plt.gca().axes.get_yaxis().set_visible(False)

# Asegurar que el eje y tiene el rango correcto
plt.ylim(0, 250)

plt.show()

# %%
display(df_FlexDrive[df_FlexDrive["P13-Posee_Veh_Propio"] == "Sí"]['P32-Interés_Propietario'].value_counts())
display(df_FlexDrive[df_FlexDrive["P13-Posee_Veh_Propio"] == "No"]['P32-Interés_Propietario'].value_counts())

display(df_FlexDrive[df_FlexDrive["P32-Interés_Propietario"] == "Sí"]['P13-Posee_Veh_Propio'].value_counts())
display(df_FlexDrive[df_FlexDrive["P32-Interés_Propietario"] == "No"]['P13-Posee_Veh_Propio'].value_counts())
# Out:
# P32-Interés_Propietario
# No    89
# Sí    57
# Name: count, dtype: int64
# P32-Interés_Propietario
# No    134
# Sí    108
# Name: count, dtype: int64
# P13-Posee_Veh_Propio
# No    108
# Sí     57
# Name: count, dtype: int64
# P13-Posee_Veh_Propio
# No    134
# Sí     89
# Name: count, dtype: int64

# %%
df_FlexDrive['P4-Ciudad'].value_counts().plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Distribución de ciudades - UsuarioS Flex Drive')
plt.xlabel('Ciudades')
plt.ylabel('Cantidad De Respuestas')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
df_FlexDrive['P7-Actividad_Actual_Multi'].value_counts().plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title('Actividades')
plt.xlabel('Actividad')
plt.ylabel('Frecuencia')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\vicen\AppData\Local\Temp\ipykernel_4640\512532006.py:6: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
import matplotlib.pyplot as plt

# Conteo individual de respuestas (ya limpias)
servicios_usados = df_FlexDrive["P10-Servicios_Públicos_Usados_Multi"].str.split(";").explode().value_counts()

# Crear la gráfica de barras
plt.figure(figsize=(10, 6))
servicios_usados.plot(kind="bar", color="#4C72B0", edgecolor="black")
plt.title("Servicios Públicos de Transporte Más Usados", fontsize=14)
plt.xlabel("Servicio", fontsize=12)
plt.ylabel("Número de Personas", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Mostrar la gráfica
plt.show()

# %%
import matplotlib.pyplot as plt

# Conteo individual de beneficios P2P
beneficios_counts = df_FlexDrive['P21-Beneficios_P2P'].str.split(";").explode().value_counts()

# Gráfica de barras
plt.figure(figsize=(10, 6))
beneficios_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Beneficios percibidos del modelo P2P', fontsize=14)
plt.xlabel('Beneficio', fontsize=12)
plt.ylabel('Cantidad de respuestas', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Conteo individual de respuestas
riesgos_p2p = df_FlexDrive["P22-Desventajas_P2P"].str.split(";").explode().value_counts()

# Gráfico de barras
plt.figure(figsize=(10, 6))
riesgos_p2p.plot(kind='bar', color='tomato', edgecolor='black')
plt.title('Riesgos percibidos del modelo P2P', fontsize=14)
plt.xlabel('Riesgo identificado', fontsize=12)
plt.ylabel('Cantidad de respuestas', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Conteo de menciones individuales (ya mapeadas)
conteo_entidades = df_FlexDrive["P29N-Entidades_Donde_Rentó[P25]"].str.split(";").explode().value_counts()

# Filtrar valores vacíos, si es necesario
conteo_entidades = conteo_entidades[conteo_entidades.index != ""]

# Gráfica de barras horizontal
plt.figure(figsize=(10, 6))
conteo_entidades.sort_values().plot(kind='barh', color='#69b3a2')
plt.title("Entidades donde los participantes han rentado vehículos previamente")
plt.xlabel("Cantidad de menciones")
plt.ylabel("Entidades o plataformas")
plt.tight_layout()
plt.grid(axis='x', linestyle='--', alpha=0.6)
plt.show()

# %%
import matplotlib.pyplot as plt

# Conteo de respuestas individuales
conteo_pagos = df_FlexDrive["P39_Recibir_Pagos_Propietario[P30]"].str.split(";").explode().value_counts()

# Gráfica de barras
plt.figure(figsize=(10, 6))
conteo_pagos.plot(kind='bar', color='skyblue')
plt.title('Preferencias de los propietarios sobre cómo recibir el pago')
plt.xlabel('Forma de pago')
plt.ylabel('Cantidad de respuestas')
plt.xticks(rotation=22, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Explota y cuenta respuestas individuales
conteo_prioridades = df_FlexDrive["P46N-Otras_Prioridades_Para_Tomar_en_Renta[41]"]\
    .str.split(";").explode().value_counts()

# Filtra respuestas no vacías o irrelevantes (opcional, si ya está limpio)
conteo_prioridades = conteo_prioridades[conteo_prioridades.index != ""]

# Gráfico de barras
plt.figure(figsize=(12, 6))
conteo_prioridades.plot(kind='bar', color="#4B9CD3")
plt.title("Otras prioridades para tomar en renta un vehículo", fontsize=14)
plt.xlabel("Prioridades mencionadas", fontsize=12)
plt.ylabel("Número de menciones", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Explota y cuenta respuestas individuales de la pregunta P7
conteo_actividad_actual = df_FlexDrive["P7-Actividad_Actual_Multi"].str.split(";").explode().value_counts()

# Opcional: filtrar respuestas vacías o irrelevantes si es necesario
conteo_actividad_actual = conteo_actividad_actual[conteo_actividad_actual.index != ""]

# Generar gráfico de barras
plt.figure(figsize=(12, 6))
conteo_actividad_actual.plot(kind='bar', color="#4CAF50")
plt.title("Actividades actuales de los encuestados", fontsize=14)
plt.xlabel("Actividad", fontsize=12)
plt.ylabel("Número de menciones", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Copia solo las columnas necesarias
df_temp = df_FlexDrive[["P7-Actividad_Actual_Multi", "P32-Interés_Propietario"]].dropna()

# Separar actividades múltiples en filas (explode)
df_temp["P7_Separada"] = df_temp["P7-Actividad_Actual_Multi"].str.split(";")
df_explode = df_temp.explode("P7_Separada")

# Eliminar espacios extra
df_explode["P7_Separada"] = df_explode["P7_Separada"].str.strip()

# Graficar boxplot
plt.figure(figsize=(12,6))
sns.boxplot(data=df_explode, x="P7_Separada", y="P32-Interés_Propietario")
plt.xticks(rotation=45, ha='right')
plt.title("Valor dispuesto a pagar según actividad actual (limpia)")
plt.xlabel("Actividad actual")
plt.ylabel("Valor dispuesto a pagar (COP)")
plt.tight_layout()
plt.show()
