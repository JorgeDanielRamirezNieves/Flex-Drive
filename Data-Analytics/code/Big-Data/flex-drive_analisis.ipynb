# %% [markdown]
# # ANÁLISIS DEL FORMULARIO 1 - PERMÍTENOS CONOCERTE | FLEX DRIVE 2025-1

# %%
import pandas as pd

pd.options.display.max_columns = 80
df_FlexDrive = pd.read_csv('../Docs/FLEX DRIVE - Permítenos Conocerte(Sheet1).csv', delimiter = ';')
df_FlexDrive.drop(columns=['Hora de inicio', 'Hora de finalizaci�n', 'Correo electr�nico', 'Nombre', 'Language'], inplace=True)
df_FlexDrive.head(10)
# Out:
#    Id  \
# 0   4
# 1   5
# 2   6
# 3   7
# 4   8
# 5   9
# 6  10
# 7  11
# 8  12
# 9  13
#
#   Queremos solicitar tu aprobaci�n para el tratamiento de datos en este formulario. Al aceptar, nos permites y conoces que Analizaremos las respuestas brindadas en el formulario �nicamente�en los inte  \
# 0                                            Acepto.
# 1                                            Acepto.
# 2                                            Acepto.
# 3                                            Acepto.
# 4                                            Acepto.
# 5                                            Acepto.
# 6                                            Acepto.
# 7                                            Acepto.
# 8                                            Acepto.
# 9                                            Acepto.
#
#   Ind�canos tu edad: Pa�s de Origen / Nacionalidad Ciudad de residencia  \
# ...
