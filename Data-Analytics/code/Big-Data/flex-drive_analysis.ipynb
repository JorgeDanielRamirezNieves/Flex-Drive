# %% [markdown]
# ## **FORMULARIO I: PERMÍTENOS CONOCERTE | FLEX DRIVE 2025-1**
# El presente modelo de análisis ha sido diseñado exclusivamente para la presentación de resultados obtenidos en el Formulario N°1 de Flex Drive, enfocado en estudiar el mercado en diversos grupos poblacionales, principalmente en el área metropolitana boyacense y algunas ciudades del casco cundiboyacense. Mediante conceptos aplicados de _estadística descriptiva_, se logra comprender las nacesidades, expectativas y percepción del público frente a la idea que representa: _Flex Drive_.
#
# Los posibles resultados (_insights_) a obtener están ligados a una pequeña muestra de [NÚMERO_FORMULARIOS], por ende, los _insights_ no presentan con total certeza la realidad actual de la población estudiada. Dada las circunstancias, la importancia y transcendencia de este avance están orientadas en la construcción del modelo, la adquisición de experiencia grupal para la logística del mercado y marcar un punto de trazabilidad en la evaluación externa de esta idea de negocio.
#
# ***
#
# En cuanto a objetivos, este software de terminal contempla:
#
# ### **Objetivos**
# 1. Descubrir las tendencias en cuanto a experiencias, gustos y preferencias de diversos grupos poblaciones frente a las propuestas planteadas desde Flex Drive.
# 2. [Definir]
# 3. [Definir]

# %% [markdown]
# ***
# ### **FASE 1 - Lectura y Limpieza de Datos**
# El Formulario N°1 de _Flex Drive_ fue realizado mediante la plataforma _Microsoft Forms_. Contando con un total de 53 preguntas posibles, donde los encuestados respondían una cantidad diferente según sus intereses y necesidades.
#
# Dentro de las responsabilidades y procesos descritos en _Flex Drive_, se contempla que este documento participa en las _Fase I_ y _II_ del **Módulo de Analítica de Datos**, donde:
#
# <table>
#   <thead>
#     <tr>
#       <th colspan="4" style="text-align: center;">MÓDULO: ANALÍTICA DE DATOS</th>
#     </tr>
#     <tr>
#       <th style="text-align: center;">Nombre</th>
#       <th style="text-align: center;">Descripción de Tareas</th>
#       <th style="text-align: center;">Responsables de Ejecución</th>
#       <th style="text-align: center;">Responsables de Aprobación</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td style="text-align: center;">Fase I</td>
#       <td style="text-align: center;">
#         <ul style="list-style-position: inside; padding-left: 0;">
#           <li>Planeación y estructura del Formulario.</li>
#           <li>Limpieza de datos Formulario.</li>
#           <li>Análisis descriptivo de los datos obtenidos por el FORM.</li>
#           <li>Caracterización de la Población encuestada.</li>
#         </ul>
#       </td>
#       <td style="text-align: center;">
#         <ul style="list-style-position: inside; padding-left: 0;">
#           <b>Unidad: </b>Análisis y Mercado
#             <li>Karoll Catalina Amaya Casallas</li>
#         </ul>
#       </td>
#       <td style="text-align: center;" rowspan="2">
#         <ul style="list-style-position: inside; padding-left: 0;">
#           <b>M.D.G</b> | Mesa Directiva General de <em>Flex Drive</em>
#           <li><b>División: </b> Arquitectura Empresarial</li>
#         </ul>
#       </td>
#     </tr>
#     <tr>
#       <td style="text-align: center;">Fase II</td>
#       <td style="text-align: center;">
#         <ul style="list-style-position: inside; padding-left: 0;">
#           <li>Descripción de las variables analizadas para el Formulario y las FASES I, III y IV.</li>
#           <li>Hipótesis sobre correlación de variables.</li>
#           <li>Descripción de la naturaleza de las varialbes, entradas requeridas y resultados esperados en cada fase.</li>
#         </ul>
#       </td>
#       <td style="text-align: center;">
#         <ul style="list-style-position: inside; padding-left: 0;">
#           <b>División: </b> Arquitectura Empresarial
#             <li>Jorge Daniel Ramírez Nieves</li><br>
#           <b>Unidad: </b>Análisis y Mercado
#             <li>Karoll Catalina Amaya Casallas</li>
#         </ul>
#       </td>
#     </tr>
#   </tbody>
# </table>
#
#
#
#
# Este formulario se encuentra dispuesto al público desde el 03 de mayo del 2025, y las diversas versiones de los resultados de este modelo depende exclusivamente de las fechas de corte dispuestas. Este formulario dará cierre una vez se cumplan algunas de las siguientes condiciones:
# - Se obtengan 1000 respuestas válidas del área metropolitana de Tunja.
# - Llegue la fecha del 01 de agosto del 2025.

# %%
import pandas as pd         # Librería Pandas: Manipular de datos

pd.options.display.max_columns = 87     # display.max_columns sirve para mostrar la cantidad de columnas que queremos.
df_FlexDrive = pd.read_excel('../../docs/FLEX DRIVE - Permítenos Conocerte.xlsx', sheet_name='Sheet1')
# df_FlexDrive.drop(columns=['Correo electr�nico', 'Nombre', 'Language'], inplace=True)
df_FlexDrive.head(10)
# Out:
#    Id         Hora_Inicio            Hora_Fin P1-Autorización P2-Edad  \
# 0   4 2025-05-02 16:20:11 2025-05-02 16:27:36         Acepto.   18-25
# 1   5 2025-05-02 16:48:53 2025-05-02 16:54:36         Acepto.   36-45
# 2   6 2025-05-02 17:13:49 2025-05-02 17:26:16         Acepto.   18-25
# 3   7 2025-05-02 17:28:53 2025-05-02 17:33:21         Acepto.   16-17
# 4   8 2025-05-02 17:29:39 2025-05-02 17:33:49         Acepto.   18-25
# 5   9 2025-05-02 17:31:13 2025-05-02 17:36:17         Acepto.   18-25
# 6  10 2025-05-02 17:42:34 2025-05-02 17:46:42         Acepto.   18-25
# 7  11 2025-05-02 17:48:51 2025-05-02 17:52:27         Acepto.   16-17
# 8  12 2025-05-02 18:07:37 2025-05-02 18:12:50         Acepto.   18-25
# 9  13 2025-05-02 18:11:08 2025-05-02 18:13:27         Acepto.   18-25
#
#     P3-País         P4-Ciudad   P5-Género          P6-Estrato  \
# 0  Colombia          Duitama    Femenino.         3 - (Medio)
# 1  Colombia  Duitama -Boyaca    Femenino.  2 - (Bajo - Medio)
# 2  Colombia     Tunja, Boyaca  Masculino.    4 - (Medio Alto)
# 3  Colombia             Tunja   Femenino.  2 - (Bajo - Medio)
# 4  Colombia            Tunja    Femenino.    4 - (Medio Alto)
# 5  Colombia            Tunja   Masculino.    4 - (Medio Alto)
# 6  Colombia             Tunja  Masculino.    4 - (Medio Alto)
# 7  Colombia             Tunja  Masculino.         3 - (Medio)
# 8  Colombia            Tunja   Masculino.         3 - (Medio)
# 9  Colombia             Tunja   Femenino.          5 - (Alto)
#
#                            P7-Actividad_Actual_Multi  \
# 0  Soy estudiante en estudios superiores o univer...
# 1                                Estoy desempleado.;
# 2  Soy freelancer / independiente.;Soy estudiante...
# 3  Soy estudiante en estudios superiores o univer...
# 4  Soy estudiante en estudios superiores o univer...
# 5  Soy estudiante en estudios superiores o univer...
# 6  Soy estudiante en estudios superiores o univer...
# 7  Soy estudiante en estudios superiores o univer...
# 8  Soy estudiante en estudios superiores o univer...
# 9  Soy estudiante en estudios superiores o univer...
#
#                                P8-Nivel_Educativo  \
# 0  Pregrado universitario (Grado o Licenciatura).
# 1                Formación Técnica o Tecnológica.
# 2  Pregrado universitario (Grado o Licenciatura).
# 3  Pregrado universitario (Grado o Licenciatura).
# 4  Pregrado universitario (Grado o Licenciatura).
# 5  Pregrado universitario (Grado o Licenciatura).
# 6  Pregrado universitario (Grado o Licenciatura).
# 7  Pregrado universitario (Grado o Licenciatura).
# 8  Pregrado universitario (Grado o Licenciatura).
# 9  Pregrado universitario (Grado o Licenciatura).
#
#   P9-Frecuencia_Uso_Servicios_Públicos P10-Servicios_Públicos_Usados_Multi  \
# 0                         Diariamente.       Taxis;Buses intermunicipales;
# 1             Únicamente entre semana.            Taxis;Buses municipales;
# 2      Únicamente los fines de semana.        Buses intermunicipales;uber;
# 3      Únicamente los fines de semana.                              Taxis;
# 4             Únicamente entre semana.            Taxis;Buses municipales;
# 5             Únicamente entre semana.            Buses municipales;Taxis;
# 6                         Diariamente.                  Buses municipales;
# 7                         Diariamente.            Buses municipales;Taxis;
# 8                         Diariamente.            Taxis;Buses municipales;
# 9                            Rara vez.            Taxis;Buses municipales;
#
#                      P11-Motivo_Desplazamiento_Multi  \
# 0  Por estudio.;Por compromisos personales o fami...
# 1                                      Por trabajo.;
# 2          Por compromisos personales o familiares.;
# 3                                      Por estudio.;
# 4                                      Por estudio.;
# 5  Por estudio.;Por compromisos personales o fami...
# 6                                      Por estudio.;
# 7  Por estudio.;Por compromisos personales o fami...
# 8  Por estudio.;Por compromisos personales o fami...
# 9                                      Por estudio.;
#
#                       P12-Estado_Licencia_Conducción P13-Posee_Veh_Propio  \
# 0  Poseo licencia de conducción vigente o próxima...                   No
# 1  Poseo licencia de conducción vigente o próxima...                   Sí
# 2  Poseo licencia de conducción vigente o próxima...                   No
# 3  Poseo licencia de conducción vigente o próxima...                   Sí
# 4  No poseo licencia, pero estoy interesado en ob...                   No
# 5  No poseo licencia, pero estoy interesado en ob...                   Sí
# 6  Poseo licencia de conducción vigente o próxima...                   No
# 7  No poseo licencia, pero estoy interesado en ob...                   No
# 8  Poseo licencia de conducción vigente o próxima...                   No
# 9  Poseo licencia de conducción vigente o próxima...                   No
#
#      P14-Frecuencia_Uso_Veh[P13] P15-Cantidad_Veh_Propios[P13]  \
# 0                            NaN                           NaN
# 1                  Muy rara vez.            Un único vehículo.
# 2                            NaN                           NaN
# 3  Solo durante fines de semana.            Un único vehículo.
# 4                            NaN                           NaN
# 5                   Diariamente.            Un único vehículo.
# 6                            NaN                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            NaN                           NaN
#
#                              P16-Modo_Uso_Veh[P15-U]  \
# 0                                                NaN
# 1  Sí, es un vehículo compartido con familiares, ...
# 2                                                NaN
# 3           No, es un vehículo completamente propio.
# 4                                                NaN
# 5  Sí, es un vehículo compartido con familiares, ...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                            P17-Tipo_Veh[P15-U] P16-Modo_Uso_Veh[P15-Multi]  \
# 0                                          NaN                         NaN
# 1  Automóvil (carros, camionetas, entre otros)                         NaN
# 2                                          NaN                         NaN
# 3                                  Moticicleta                         NaN
# 4                                          NaN                         NaN
# 5  Automóvil (carros, camionetas, entre otros)                         NaN
# 6                                          NaN                         NaN
# 7                                          NaN                         NaN
# 8                                          NaN                         NaN
# 9                                          NaN                         NaN
#
#   P17-Tipo_Veh]P15-Multi] P18-Conoce_P2P  \
# 0                     NaN             Sí
# 1                     NaN             No
# 2                     NaN             No
# 3                     NaN             Sí
# 4                     NaN             No
# 5                     NaN             Sí
# 6                     NaN             No
# 7                     NaN             No
# 8                     NaN             No
# 9                     NaN             No
#
#                                   P19-Beneficios_P2P  \
# 0  Mayor flexibilidad en horarios.;Experiencia de...
# 1  Mayor flexibilidad en horarios.;Posibilidad de...
# 2  Aprovechamiento de vehículos particulares inac...
# 3  Aprovechamiento de vehículos particulares inac...
# 4  Posibilidad de generar ingresos como propietar...
# 5  Posibilidad de generar ingresos como propietar...
# 6  Posibilidad de generar ingresos como propietar...
# 7  Mejor negociación en condiciones de arriendo.;...
# 8  Mejor negociación en condiciones de arriendo.;...
# 9  Posibilidad de generar ingresos como propietar...
#
#                                  P20-Desventajas_P2P P21-Ha_Rentado_Su_Veh  \
# 0  Posibles daños o mal uso del vehículo rentado....                    No
# 1  Posibles daños o mal uso del vehículo rentado....                    No
# 2  Posibles daños o mal uso del vehículo rentado....                    No
# 3  Posibles daños o mal uso del vehículo rentado....                    No
# 4  Desconfianza frente a clientes / personas desc...                    No
# 5  Posibles daños o mal uso del vehículo rentado....                    No
# 6  Posibles daños o mal uso del vehículo rentado....                    No
# 7  Posibles daños o mal uso del vehículo rentado....                    No
# 8  Posibles daños o mal uso del vehículo rentado....                    No
# 9  Posibles daños o mal uso del vehículo rentado....                    No
#
#   P22N-Forma_Renta[P21] P23N-Aspectos_Positivos_Exp[P21]  \
# 0                   NaN                              NaN
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3                   NaN                              NaN
# 4                   NaN                              NaN
# 5                   NaN                              NaN
# 6                   NaN                              NaN
# 7                   NaN                              NaN
# 8                   NaN                              NaN
# 9                   NaN                              NaN
#
#   P24N-Aspectos_Negativos_Exp2[P21] P25-Ha_Tomado_En_Renta  \
# 0                               NaN                     No
# 1                               NaN                     No
# 2                               NaN                     Sí
# 3                               NaN                     No
# 4                               NaN                     No
# 5                               NaN                     Sí
# 6                               NaN                     No
# 7                               NaN                     No
# 8                               NaN                     Sí
# 9                               NaN                     No
#
#   P26N-Lugar_donde_Rentó[P25] P27N-Entidades_Donde_Rentó[P25]  \
# 0                         NaN                             NaN
# 1                         NaN                             NaN
# 2                         NaN                        Localiza
# 3                         NaN                             NaN
# 4                         NaN                             NaN
# 5                         NaN                             NaN
# 6                         NaN                             NaN
# 7                         NaN                             NaN
# 8                         NaN                             NaN
# 9                         NaN                             NaN
#
#                     P28N-Beneficios_Experiencia[P25]  \
# 0                                                NaN
# 1                                                NaN
# 2  Facilidad en el acceso al servicio.;Transparen...
# 3                                                NaN
# 4                                                NaN
# 5  Facilidad en el acceso al servicio.;Rapidez en...
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                   P29N-Desventajas_Experiencia[P25]  \
# 0                                               NaN
# 1                                               NaN
# 2  Costos elevados en comparación con lo esperado.;
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
#
#                              P30-Interés_Propietario  \
# 0  Sí, me llama la atención en el presente o futuro.
# 1                  No me llama la atención, gracias.
# 2  Sí, me llama la atención en el presente o futuro.
# 3                  No me llama la atención, gracias.
# 4                  No me llama la atención, gracias.
# 5                  No me llama la atención, gracias.
# 6                  No me llama la atención, gracias.
# 7                  No me llama la atención, gracias.
# 8                  No me llama la atención, gracias.
# 9  Sí, me llama la atención en el presente o futuro.
#
#                    P31-Modo_Preferido_Renta_Veh[P30]  \
# 0                         Solo los fines de semana.;
# 1                                                NaN
# 2              Por horas.;Por días (cualquier día).;
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Por días (cualquier día).;A disposición person...
#
#   P32[A]-Prioridad:Seguro_Vehicular[P30] P32[B]-Prioridad:GPS_Vehicular[P30]  \
# 0                       🔴Prioridad Alta🔴                    🔴Prioridad Alta🔴
# 1                                    NaN                                 NaN
# 2                       🔴Prioridad Alta🔴                    🟢Prioridad Baja🟢
# 3                                    NaN                                 NaN
# 4                                    NaN                                 NaN
# 5                                    NaN                                 NaN
# 6                                    NaN                                 NaN
# 7                                    NaN                                 NaN
# 8                                    NaN                                 NaN
# 9                       🔴Prioridad Alta🔴                    🔴Prioridad Alta🔴
#
#   P32[C]-Prioridad:Autentificar_Todos_Los_Users[P30]  \
# 0                                   🔴Prioridad Alta🔴
# 1                                                NaN
# 2                                   🔴Prioridad Alta🔴
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                  🟡Prioridad Media🟡
#
#   P32[D]-Prioridad:Seguridad_Pagos_Plataforma[P30]  \
# 0                                 🔴Prioridad Alta🔴
# 1                                              NaN
# 2                                 🔴Prioridad Alta🔴
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# 8                                              NaN
# 9                                 🔴Prioridad Alta🔴
#
#   P32[E]-Prioridad:Comunicación_Directa_Cliente[P30]  \
# 0                                   🔴Prioridad Alta🔴
# 1                                                NaN
# 2                                   🔴Prioridad Alta🔴
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                  🟡Prioridad Media🟡
#
#   P32[F]-Prioridad:Apoyo_Precios[P30]  \
# 0                    🔴Prioridad Alta🔴
# 1                                 NaN
# 2                    🔴Prioridad Alta🔴
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                    🟢Prioridad Baja🟢
#
#   P32[G]-Prioridad:Contratos_Automáticos[P30]  \
# 0                            🔴Prioridad Alta🔴
# 1                                         NaN
# 2                            🔴Prioridad Alta🔴
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                            🔴Prioridad Alta🔴
#
#   P32[H]-Prioridad:Variedad_Pagos[P30] P32[I]-Prioridad:Reseñas_Clientes[P30]  \
# 0                     🔴Prioridad Alta🔴                       🔴Prioridad Alta🔴
# 1                                  NaN                                    NaN
# 2                     🟢Prioridad Baja🟢                       🔴Prioridad Alta🔴
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
# 5                                  NaN                                    NaN
# 6                                  NaN                                    NaN
# 7                                  NaN                                    NaN
# 8                                  NaN                                    NaN
# 9                     🟢Prioridad Baja🟢                      🟡Prioridad Media🟡
#
#   P32[J]-Prioridad:Contacto_FlexDrive[P30]  \
# 0                        🟡Prioridad Media🟡
# 1                                      NaN
# 2                         🔴Prioridad Alta🔴
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                         🔴Prioridad Alta🔴
#
#   P32[K]-Prioridad:Asistencia_Legal[P30]  \
# 0                       🔴Prioridad Alta🔴
# 1                                    NaN
# 2                       🔴Prioridad Alta🔴
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                       🔴Prioridad Alta🔴
#
#   P32[L]-Prioridad:Apoyo_Cómo_Cobrar[P30]  \
# 0                        🔴Prioridad Alta🔴
# 1                                     NaN
# 2                       🟡Prioridad Media🟡
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                       🟡Prioridad Media🟡
#
#                          P33N-Otras_Prioridades[P30]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Seguridad al conocer quien es la persona que v...
#
#                      P34-Modelo_Confianza_Multi[P30]  \
# 0  Pueda configurar qué tipo de solicitudes quier...
# 1                                                NaN
# 2  Pueda configurar qué tipo de solicitudes quier...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Pueda configurar qué tipo de solicitudes quier...
#
#              P35-Precio_Horas_Propietario_Multi[P30]  \
# 0                  Entre $30.000 a $50.000 la hora.;
# 1                                                NaN
# 2                  Entre $15.000 a $30.000 la hora.;
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Entre $30.000 a $50.000 la hora.;Entre $50.000...
#
#                P36_Precio_Dia_Propietario_Multi[P30]  \
# 0    No me encuentro interesado en rentar por días.;
# 1                                                NaN
# 2                 Entre $100.000 a $150.000 el día.;
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Entre $200.000 a $250.000 el día.;Entre $250.0...
#
#                   P37_Recibir_Pagos_Propietario[P30]  \
# 0  En efectivo, antes de entregar el vehículo al ...
# 1                                                NaN
# 2  Un respaldo con un pagaré automatizado por tra...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  En efectivo, antes de entregar el vehículo al ...
#
#   P38[A]-Confianza:Edad_Experiencia_Cliente[P30]  \
# 0                               🔴Prioridad Alta🔴
# 1                                            NaN
# 2                              🟡Prioridad Media🟡
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                              🟡Prioridad Media🟡
#
#   P38[B]-Confianza:Antecedentes_Cliente[P30]  \
# 0                           🔴Prioridad Alta🔴
# 1                                        NaN
# 2                           🔴Prioridad Alta🔴
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                           🔴Prioridad Alta🔴
#
#   P38[C]-Confianza:Medio_Pago_Ofertado[P30]  \
# 0                          🔴Prioridad Alta🔴
# 1                                       NaN
# 2                          🔴Prioridad Alta🔴
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                          🟢Prioridad Baja🟢
#
#   P38[D]-Confianza:Calificación_Que_Tiene_El_Cliente[P30]  \
# 0                                   🔴Prioridad Alta🔴
# 1                                                NaN
# 2                                   🔴Prioridad Alta🔴
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                   🔴Prioridad Alta🔴
#
#   P38[E]-Confianza:Motivo_Solicitud[P30]  \
# 0                      🟡Prioridad Media🟡
# 1                                    NaN
# 2                      🟡Prioridad Media🟡
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                       🟢Prioridad Baja🟢
#
#   P39N-Otros_Motivos_Para_Rentar_Seguro[P30]  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                  La ubicación de mi carro.
#
#                P40-Pago_FlexDrive_Propietarios[P30]  \
# 0  No estaría interesado en pagar comisión alguna.;
# 1                                               NaN
# 2  No estaría interesado en pagar comisión alguna.;
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9  No estaría interesado en pagar comisión alguna.;
#
#                                 P41-Interés_Cliente  \
# 0  ¡Sí, me apuntaría en el presente o en el futuro!
# 1                 No me llama la atención, gracias.
# 2  ¡Sí, me apuntaría en el presente o en el futuro!
# 3                 No me llama la atención, gracias.
# 4  ¡Sí, me apuntaría en el presente o en el futuro!
# 5  ¡Sí, me apuntaría en el presente o en el futuro!
# 6                 No me llama la atención, gracias.
# 7                 No me llama la atención, gracias.
# 8                 No me llama la atención, gracias.
# 9  ¡Sí, me apuntaría en el presente o en el futuro!
#
#   P42-Modo_Preferido_Renta_Veh[P41]  \
# 0                        Por días.;
# 1                               NaN
# 2                        Por días.;
# 3                               NaN
# 4                       Por horas.;
# 5             Por horas.;Por días.;
# 6                               NaN
# 7                               NaN
# 8                               NaN
# 9             Por días.;Por horas.;
#
#   P43[A]-Prioridad:Comunicación_Propietario[P41]  \
# 0                               🔴Prioridad Alta🔴
# 1                                            NaN
# 2                               🟢Prioridad Baja🟢
# 3                                            NaN
# 4                               🔴Prioridad Alta🔴
# 5                               🔴Prioridad Alta🔴
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                               🔴Prioridad Alta🔴
#
#   P43[B]-Prioridad:Facilidad_Variedad_Pagos[P41]  \
# 0                               🔴Prioridad Alta🔴
# 1                                            NaN
# 2                               🟢Prioridad Baja🟢
# 3                                            NaN
# 4                               🔴Prioridad Alta🔴
# 5                               🔴Prioridad Alta🔴
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                               🟢Prioridad Baja🟢
#
#   P43[C]-Prioridad:Variedad_Seguros[P41]  \
# 0                       🔴Prioridad Alta🔴
# 1                                    NaN
# 2                       🔴Prioridad Alta🔴
# 3                                    NaN
# 4                       🔴Prioridad Alta🔴
# 5                      🟡Prioridad Media🟡
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                       🔴Prioridad Alta🔴
#
#   P43[D]-Prioridad:Verificación_Usuarios[P41]  \
# 0                            🔴Prioridad Alta🔴
# 1                                         NaN
# 2                            🔴Prioridad Alta🔴
# 3                                         NaN
# 4                           🟡Prioridad Media🟡
# 5                            🔴Prioridad Alta🔴
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                           🟡Prioridad Media🟡
#
#   P43[E]-Prioridad:Apoyo_Dudas[P42] P43[F]-Prioridad:Precios_y_Ofertas[P41]  \
# 0                  🔴Prioridad Alta🔴                        🔴Prioridad Alta🔴
# 1                               NaN                                     NaN
# 2                  🔴Prioridad Alta🔴                        🔴Prioridad Alta🔴
# 3                               NaN                                     NaN
# 4                  🔴Prioridad Alta🔴                       🟡Prioridad Media🟡
# 5                 🟡Prioridad Media🟡                       🟡Prioridad Media🟡
# 6                               NaN                                     NaN
# 7                               NaN                                     NaN
# 8                               NaN                                     NaN
# 9                 🟡Prioridad Media🟡                        🔴Prioridad Alta🔴
#
#   P43[G]-Prioridad:Comunicación_FlexDrive[P41]  \
# 0                             🔴Prioridad Alta🔴
# 1                                          NaN
# 2                             🔴Prioridad Alta🔴
# 3                                          NaN
# 4                             🔴Prioridad Alta🔴
# 5                             🔴Prioridad Alta🔴
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                            🟡Prioridad Media🟡
#
#   P43[H]-Prioridad:Reseñar_Propietarios[P41]  \
# 0                          🟡Prioridad Media🟡
# 1                                        NaN
# 2                           🔴Prioridad Alta🔴
# 3                                        NaN
# 4                           🔴Prioridad Alta🔴
# 5                          🟡Prioridad Media🟡
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                           🔴Prioridad Alta🔴
#
#   P43[I]-Prioridad:Modelo_Renta_en_15MINS[P41]  \
# 0                             🔴Prioridad Alta🔴
# 1                                          NaN
# 2                             🟢Prioridad Baja🟢
# 3                                          NaN
# 4                             🔴Prioridad Alta🔴
# 5                            🟡Prioridad Media🟡
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                             🔴Prioridad Alta🔴
#
#   P43[J]-Prioridad:Modelo_Negociación[P41]  \
# 0                         🔴Prioridad Alta🔴
# 1                                      NaN
# 2                        🟡Prioridad Media🟡
# 3                                      NaN
# 4                         🔴Prioridad Alta🔴
# 5                        🟡Prioridad Media🟡
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                         🔴Prioridad Alta🔴
#
#       P44N-Otras_Prioridades_Para_Tomar_en_Renta[41]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  La coherencia entre el precio de alquiler y em...
#
#   P45-Precio_Horas_Cliente_Multi[P41]  \
# 0   Entre $15.000 a $30.000 la hora.;
# 1                                 NaN
# 2   Entre $15.000 a $30.000 la hora.;
# 3                                 NaN
# 4   Entre $15.000 a $30.000 la hora.;
# 5   Entre $30.000 a $50.000 la hora.;
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9   Entre $15.000 a $30.000 la hora.;
#
#                    P46-Precio_Dia_Cliente_Multi[P41]  \
# 0                 Entre $100.000 a $150.000 el día.;
# 1                                                NaN
# 2                 Entre $100.000 a $150.000 el día.;
# 3                                                NaN
# 4                 Entre $100.000 a $150.000 el día.;
# 5                 Entre $100.000 a $150.000 el día.;
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Entre $150.000 a $200.000 el día.;Entre $100.0...
#
#   P47[A]-Confianza:Negociar_con_Propietario[P41]  \
# 0                               🔴Prioridad Alta🔴
# 1                                            NaN
# 2                               🟢Prioridad Baja🟢
# 3                                            NaN
# 4                              🟡Prioridad Media🟡
# 5                              🟡Prioridad Media🟡
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                              🟡Prioridad Media🟡
#
#   P47[B]-Confianza:Antigüedad_Veh[P41]  \
# 0                    🟡Prioridad Media🟡
# 1                                  NaN
# 2                     🔴Prioridad Alta🔴
# 3                                  NaN
# 4                     🟢Prioridad Baja🟢
# 5                    🟡Prioridad Media🟡
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
# 9                     🟢Prioridad Baja🟢
#
#   P47[C]-Confianza:Medio_de_Pago_Recibido[P41]  \
# 0                             🔴Prioridad Alta🔴
# 1                                          NaN
# 2                             🟢Prioridad Baja🟢
# 3                                          NaN
# 4                             🔴Prioridad Alta🔴
# 5                             🔴Prioridad Alta🔴
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                             🟢Prioridad Baja🟢
#
#   P47[D]-Confianza:Reseñas_Veh[P41] P47[E]-Confianza:Reseñas_Propietario[P41]  \
# 0                  🔴Prioridad Alta🔴                          🔴Prioridad Alta🔴
# 1                               NaN                                       NaN
# 2                  🔴Prioridad Alta🔴                          🔴Prioridad Alta🔴
# 3                               NaN                                       NaN
# 4                  🔴Prioridad Alta🔴                          🔴Prioridad Alta🔴
# 5                  🔴Prioridad Alta🔴                          🔴Prioridad Alta🔴
# 6                               NaN                                       NaN
# 7                               NaN                                       NaN
# 8                               NaN                                       NaN
# 9                  🔴Prioridad Alta🔴                          🔴Prioridad Alta🔴
#
#   P47[F]-Confianza:Claridad_Contrato[P41]  \
# 0                        🔴Prioridad Alta🔴
# 1                                     NaN
# 2                        🔴Prioridad Alta🔴
# 3                                     NaN
# 4                        🔴Prioridad Alta🔴
# 5                        🔴Prioridad Alta🔴
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                       🟡Prioridad Media🟡
#
#   P47[G]-Confianza:Punto_Entrega_Devolución_Vehículo[P41]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#   P47[H]-Confianza:Revisión_Tecnicomecánica_Veh[P41]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#         P48N-Otros_Puntos_Confianza_para_Rentar[P41] P49-Idea_FlexDrive  \
# 0                                                NaN              Clara
# 1                                                NaN              Clara
# 2  punto de recogida y punto de entrega del vehiculo              Clara
# 3                                                NaN              Clara
# 4                                                NaN              Clara
# 5                                                NaN              Clara
# 6                                                NaN              Clara
# 7                                                NaN              Clara
# 8                                                NaN              Clara
# 9  El estado del carro, no solo en la carrocería ...              Clara
#
#                                P50-Usaría_FlexDrive…  \
# 0  Probable - Me gustaría conocer más de la plata...
# 1  Neutral - Es un buen concepto que requiere más...
# 2  Muy probable - Me gustaría inscribirme en la p...
# 3  Neutral - Es un buen concepto que requiere más...
# 4  Neutral - Es un buen concepto que requiere más...
# 5  Muy probable - Me gustaría inscribirme en la p...
# 6  Muy improbable - No me encuentro interesado o ...
# 7  Neutral - Es un buen concepto que requiere más...
# 8  Neutral - Es un buen concepto que requiere más...
# 9  Probable - Me gustaría conocer más de la plata...
#
#      P51-Preferencias_para_Comunicarse_con_FlexDrive
# 0  Por chat con asesor mediante Whatsapp.;Con un ...
# 1  Por llamada telefónica.;Por chat con asesor me...
# 2  Un chat en la plataforma.;Por llamada telefóni...
# 3  Un chat en la plataforma.;Por llamada telefóni...
# 4  Un chat en la plataforma.;Por correo electróni...
# 5  Un chat en la plataforma.;Por chat con asesor ...
# 6            Por chat con asesor mediante Whatsapp.;
# 7  Por chat con asesor mediante Whatsapp.;Por lla...
# 8  Por correo electrónico.;Por chat con asesor me...
# 9            Por chat con asesor mediante Whatsapp.;
